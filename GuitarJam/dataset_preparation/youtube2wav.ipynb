# %% [markdown]
# ## Setup

# %%
# !pip install yt-dlp pytube ffmpeg-python
# !pip install librosa soundfile
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.12.6)
# Requirement already satisfied: pytube in /usr/local/lib/python3.10/dist-packages (15.0.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)

# %%
# for youtube2wav
import os
from pytube import Search
from yt_dlp import YoutubeDL
import ffmpeg

# for wav preprocessing
from typing import List
import glob
import shutil
import librosa
import soundfile as sf
import os
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### YouTube2Wav

# %%
# Step 1: Search YouTube for Videos
def search_youtube(keyword, max_results=15):
    search = Search(keyword)
    results = search.results[:max_results]
    video_links = [f"https://www.youtube.com/watch?v={video.video_id}" for video in results]
    return video_links

# Step 2: Download and Convert Videos
def download_and_convert_to_wav(video_links, output_folder="./downloads"):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': os.path.join(output_folder, '%(title)s.%(ext)s'),
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with YoutubeDL(ydl_opts) as ydl:
        for link in video_links:
            try:
                ydl.download([link])
            except Exception as e:
                print(f"Failed to download {link}: {e}")

# Main Workflow
def get_yt_music(keywords: str = "guitar jamming session", max_results: int = 20):
    print(f"Searching YouTube for: {keywords}")
    video_links = search_youtube(keywords, max_results)
    print(f"Found {len(video_links)} videos:", "\n".join(video_links))

    print("\nDownloading and converting to .wav...")
    download_and_convert_to_wav(video_links, output_folder = f"./downloads/{keywords}")
    print("\nProcess complete!")

# %%
get_yt_music("guitar jamming session", 20)
get_yt_music("jazz guitar trio", 20)
get_yt_music("neo soul guitar instrumental live record", 20)
get_yt_music("best acoustic guitar rock songs", 20)
get_yt_music("guitar live performance old songs", 20)
# Out:
# Searching YouTube for: guitar jamming session
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: guitar jamming session
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: guitar jamming session
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: guitar jamming session
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Found 18 videos: https://www.youtube.com/watch?v=HspKIEa1qwk
# https://www.youtube.com/watch?v=f6dnI1WsFrA
# https://www.youtube.com/watch?v=Hmn0p5JwK-w
# https://www.youtube.com/watch?v=btAvJJT9kys
# https://www.youtube.com/watch?v=sPqPN18BsVQ
# https://www.youtube.com/watch?v=P9-kzchT3dE
# https://www.youtube.com/watch?v=hu7PKBhBqLw
# https://www.youtube.com/watch?v=2E0s2H-lQoI
# https://www.youtube.com/watch?v=AVML8rtc7hw
# https://www.youtube.com/watch?v=L1Bg94UspU0
# https://www.youtube.com/watch?v=Feg3wrZP0Pk
# https://www.youtube.com/watch?v=mPcGJahjsHY
# https://www.youtube.com/watch?v=cUFVR5sgbt0
# https://www.youtube.com/watch?v=3rkwBiMhZjM
# https://www.youtube.com/watch?v=BsbcDSDuILY
# https://www.youtube.com/watch?v=q7RhqX2t9A4
# https://www.youtube.com/watch?v=fGFd5Gzn5Is
# https://www.youtube.com/watch?v=vd38lhfJQwk
#
# Downloading and converting to .wav...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HspKIEa1qwk
# [youtube] HspKIEa1qwk: Downloading webpage
# [youtube] HspKIEa1qwk: Downloading ios player API JSON
# [youtube] HspKIEa1qwk: Downloading mweb player API JSON
# [youtube] HspKIEa1qwk: Downloading m3u8 information
# [info] HspKIEa1qwk: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Jam Session! Henny Hendrexz, Michael Lemmo & Conrad Lee at Norman's Rare Guitars.webm
# [download] 100% of    4.92MiB in 00:00:00 at 12.64MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Jam Session! Henny Hendrexz, Michael Lemmo & Conrad Lee at Norman's Rare Guitars.wav
# Deleting original file ./downloads/guitar jamming session/Jam Session! Henny Hendrexz, Michael Lemmo & Conrad Lee at Norman's Rare Guitars.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=f6dnI1WsFrA
# [youtube] f6dnI1WsFrA: Downloading webpage
# [youtube] f6dnI1WsFrA: Downloading ios player API JSON
# [youtube] f6dnI1WsFrA: Downloading mweb player API JSON
# [youtube] f6dnI1WsFrA: Downloading m3u8 information
# [info] f6dnI1WsFrA: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/BB King & John Mayer Live ｜ Improv Jam ｜ Part 1.webm
# [download] 100% of    8.54MiB in 00:00:00 at 25.30MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/BB King & John Mayer Live ｜ Improv Jam ｜ Part 1.wav
# Deleting original file ./downloads/guitar jamming session/BB King & John Mayer Live ｜ Improv Jam ｜ Part 1.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Hmn0p5JwK-w
# [youtube] Hmn0p5JwK-w: Downloading webpage
# [youtube] Hmn0p5JwK-w: Downloading ios player API JSON
# [youtube] Hmn0p5JwK-w: Downloading mweb player API JSON
# [youtube] Hmn0p5JwK-w: Downloading m3u8 information
# [info] Hmn0p5JwK-w: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Isn't She Lovely (Stevie Wonder Guitar Cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.webm
# [download] 100% of   11.73MiB in 00:00:00 at 21.98MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Isn't She Lovely (Stevie Wonder Guitar Cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.wav
# Deleting original file ./downloads/guitar jamming session/Isn't She Lovely (Stevie Wonder Guitar Cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=btAvJJT9kys
# [youtube] btAvJJT9kys: Downloading webpage
# [youtube] btAvJJT9kys: Downloading ios player API JSON
# [youtube] btAvJJT9kys: Downloading mweb player API JSON
# [youtube] btAvJJT9kys: Downloading m3u8 information
# [info] btAvJJT9kys: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Soulful Blues Groove Guitar Backing Track Jam in A Minor.webm
# [download] 100% of   11.00MiB in 00:00:00 at 36.41MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Soulful Blues Groove Guitar Backing Track Jam in A Minor.wav
# Deleting original file ./downloads/guitar jamming session/Soulful Blues Groove Guitar Backing Track Jam in A Minor.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sPqPN18BsVQ
# [youtube] sPqPN18BsVQ: Downloading webpage
# [youtube] sPqPN18BsVQ: Downloading ios player API JSON
# [youtube] sPqPN18BsVQ: Downloading mweb player API JSON
# [youtube] sPqPN18BsVQ: Downloading m3u8 information
# [info] sPqPN18BsVQ: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Funk Jam w⧸ Josh Smith, Kirk Fletcher and Ariel Posen at NAMM 2018.webm
# [download] 100% of   10.61MiB in 00:00:00 at 39.75MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Funk Jam w⧸ Josh Smith, Kirk Fletcher and Ariel Posen at NAMM 2018.wav
# Deleting original file ./downloads/guitar jamming session/Funk Jam w⧸ Josh Smith, Kirk Fletcher and Ariel Posen at NAMM 2018.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=P9-kzchT3dE
# [youtube] P9-kzchT3dE: Downloading webpage
# [youtube] P9-kzchT3dE: Downloading ios player API JSON
# [youtube] P9-kzchT3dE: Downloading mweb player API JSON
# [youtube] P9-kzchT3dE: Downloading m3u8 information
# [info] P9-kzchT3dE: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/(Full Video) The Best Jam I’ve Ever Witnessed ⧸ The Left Leg Jam.webm
# [download] 100% of   46.74MiB in 00:00:03 at 12.02MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/(Full Video) The Best Jam I’ve Ever Witnessed ⧸ The Left Leg Jam.wav
# Deleting original file ./downloads/guitar jamming session/(Full Video) The Best Jam I’ve Ever Witnessed ⧸ The Left Leg Jam.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hu7PKBhBqLw
# [youtube] hu7PKBhBqLw: Downloading webpage
# [youtube] hu7PKBhBqLw: Downloading ios player API JSON
# [youtube] hu7PKBhBqLw: Downloading mweb player API JSON
# [youtube] hu7PKBhBqLw: Downloading m3u8 information
# [info] hu7PKBhBqLw: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Isaiah Sharkey & Melanie Faye R&B Jam!!.webm
# [download] 100% of    4.41MiB in 00:00:00 at 10.23MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Isaiah Sharkey & Melanie Faye R&B Jam!!.wav
# Deleting original file ./downloads/guitar jamming session/Isaiah Sharkey & Melanie Faye R&B Jam!!.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2E0s2H-lQoI
# [youtube] 2E0s2H-lQoI: Downloading webpage
# [youtube] 2E0s2H-lQoI: Downloading ios player API JSON
# [youtube] 2E0s2H-lQoI: Downloading mweb player API JSON
# [youtube] 2E0s2H-lQoI: Downloading m3u8 information
# [info] 2E0s2H-lQoI: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Late night guitar jam on the Gaither cruise..webm
# [download] 100% of   46.20MiB in 00:00:05 at 8.60MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Late night guitar jam on the Gaither cruise..wav
# Deleting original file ./downloads/guitar jamming session/Late night guitar jam on the Gaither cruise..webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AVML8rtc7hw
# [youtube] AVML8rtc7hw: Downloading webpage
# [youtube] AVML8rtc7hw: Downloading ios player API JSON
# [youtube] AVML8rtc7hw: Downloading mweb player API JSON
# [youtube] AVML8rtc7hw: Downloading m3u8 information
# [info] AVML8rtc7hw: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Jam Sessions(1) #qatar #bassguitar #sessionmusician #worshipmusic #fender #drumcover.webm
# [download] 100% of  517.65KiB in 00:00:00 at 2.18MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Jam Sessions(1) #qatar #bassguitar #sessionmusician #worshipmusic #fender #drumcover.wav
# Deleting original file ./downloads/guitar jamming session/Jam Sessions(1) #qatar #bassguitar #sessionmusician #worshipmusic #fender #drumcover.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L1Bg94UspU0
# [youtube] L1Bg94UspU0: Downloading webpage
# [youtube] L1Bg94UspU0: Downloading ios player API JSON
# [youtube] L1Bg94UspU0: Downloading mweb player API JSON
# [youtube] L1Bg94UspU0: Downloading m3u8 information
# [info] L1Bg94UspU0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Arthur Nery (Live Jam Session).webm
# [download] 100% of    3.74MiB in 00:00:00 at 10.89MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Arthur Nery (Live Jam Session).wav
# Deleting original file ./downloads/guitar jamming session/Arthur Nery (Live Jam Session).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Feg3wrZP0Pk
# [youtube] Feg3wrZP0Pk: Downloading webpage
# [youtube] Feg3wrZP0Pk: Downloading ios player API JSON
# [youtube] Feg3wrZP0Pk: Downloading mweb player API JSON
# [youtube] Feg3wrZP0Pk: Downloading m3u8 information
# [info] Feg3wrZP0Pk: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/An INCREDIBLE Guitar Jam with Matteo Mancuso.webm
# [download] 100% of   10.24MiB in 00:00:00 at 20.29MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/An INCREDIBLE Guitar Jam with Matteo Mancuso.wav
# Deleting original file ./downloads/guitar jamming session/An INCREDIBLE Guitar Jam with Matteo Mancuso.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mPcGJahjsHY
# [youtube] mPcGJahjsHY: Downloading webpage
# [youtube] mPcGJahjsHY: Downloading ios player API JSON
# [youtube] mPcGJahjsHY: Downloading mweb player API JSON
# [youtube] mPcGJahjsHY: Downloading m3u8 information
# [info] mPcGJahjsHY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Albert King & Stevie Ray Vaughan - Blues Jam Session.webm
# [download] 100% of   90.41MiB in 00:00:03 at 28.35MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Albert King & Stevie Ray Vaughan - Blues Jam Session.wav
# Deleting original file ./downloads/guitar jamming session/Albert King & Stevie Ray Vaughan - Blues Jam Session.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cUFVR5sgbt0
# [youtube] cUFVR5sgbt0: Downloading webpage
# [youtube] cUFVR5sgbt0: Downloading ios player API JSON
# [youtube] cUFVR5sgbt0: Downloading mweb player API JSON
# [youtube] cUFVR5sgbt0: Downloading m3u8 information
# [info] cUFVR5sgbt0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Amazing jam session - Three random guys sing together.webm
# [download] 100% of    3.47MiB in 00:00:00 at 11.11MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Amazing jam session - Three random guys sing together.wav
# Deleting original file ./downloads/guitar jamming session/Amazing jam session - Three random guys sing together.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3rkwBiMhZjM
# [youtube] 3rkwBiMhZjM: Downloading webpage
# [youtube] 3rkwBiMhZjM: Downloading ios player API JSON
# [youtube] 3rkwBiMhZjM: Downloading mweb player API JSON
# [youtube] 3rkwBiMhZjM: Downloading m3u8 information
# [info] 3rkwBiMhZjM: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/How to Lead a Jam Session.webm
# [download] 100% of    7.92MiB in 00:00:00 at 16.60MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/How to Lead a Jam Session.wav
# Deleting original file ./downloads/guitar jamming session/How to Lead a Jam Session.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BsbcDSDuILY
# [youtube] BsbcDSDuILY: Downloading webpage
# [youtube] BsbcDSDuILY: Downloading ios player API JSON
# [youtube] BsbcDSDuILY: Downloading mweb player API JSON
# [youtube] BsbcDSDuILY: Downloading m3u8 information
# [info] BsbcDSDuILY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/AMAZING JAM! Henny Hendrexz, Tim Pierce, Conrad Lee & Jason Scheff at Norman's Rare Guitars.webm
# [download] 100% of    9.11MiB in 00:00:00 at 25.08MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/AMAZING JAM! Henny Hendrexz, Tim Pierce, Conrad Lee & Jason Scheff at Norman's Rare Guitars.wav
# Deleting original file ./downloads/guitar jamming session/AMAZING JAM! Henny Hendrexz, Tim Pierce, Conrad Lee & Jason Scheff at Norman's Rare Guitars.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=q7RhqX2t9A4
# [youtube] q7RhqX2t9A4: Downloading webpage
# [youtube] q7RhqX2t9A4: Downloading ios player API JSON
# [youtube] q7RhqX2t9A4: Downloading mweb player API JSON
# [youtube] q7RhqX2t9A4: Downloading m3u8 information
# [info] q7RhqX2t9A4: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/John Fogerty & ZZ Top - Blues & Bayous Tour In-Studio Jam Session.webm
# [download] 100% of    5.25MiB in 00:00:00 at 16.02MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/John Fogerty & ZZ Top - Blues & Bayous Tour In-Studio Jam Session.wav
# Deleting original file ./downloads/guitar jamming session/John Fogerty & ZZ Top - Blues & Bayous Tour In-Studio Jam Session.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fGFd5Gzn5Is
# [youtube] fGFd5Gzn5Is: Downloading webpage
# [youtube] fGFd5Gzn5Is: Downloading ios player API JSON
# [youtube] fGFd5Gzn5Is: Downloading mweb player API JSON
# [youtube] fGFd5Gzn5Is: Downloading m3u8 information
# [info] fGFd5Gzn5Is: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/Ain't no sunshine (cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.webm
# [download] 100% of    7.00MiB in 00:00:00 at 14.28MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/Ain't no sunshine (cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.wav
# Deleting original file ./downloads/guitar jamming session/Ain't no sunshine (cover) ⧸ DRUNK SESSION ⧸ CAPTAIN OG X Shotaro Miyamoto.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vd38lhfJQwk
# [youtube] vd38lhfJQwk: Downloading webpage
# [youtube] vd38lhfJQwk: Downloading ios player API JSON
# [youtube] vd38lhfJQwk: Downloading mweb player API JSON
# [youtube] vd38lhfJQwk: Downloading m3u8 information
# [info] vd38lhfJQwk: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar jamming session/The best jam I’ve ever witnessed (2⧸6).webm
# [download] 100% of    5.58MiB in 00:00:00 at 17.51MiB/s
# [ExtractAudio] Destination: ./downloads/guitar jamming session/The best jam I’ve ever witnessed (2⧸6).wav
# Deleting original file ./downloads/guitar jamming session/The best jam I’ve ever witnessed (2⧸6).webm (pass -k to keep)
#
# Process complete!
# Searching YouTube for: jazz guitar trio
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: jazz guitar trio
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: jazz guitar trio
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: jazz guitar trio
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: jazz guitar trio
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Found 18 videos: https://www.youtube.com/watch?v=eGgraRbGduI
# https://www.youtube.com/watch?v=eJNQmU6UmEA
# https://www.youtube.com/watch?v=W2_gdQ20Mc8
# https://www.youtube.com/watch?v=xkLA7VHpGSQ
# https://www.youtube.com/watch?v=uTM67UhBVxk
# https://www.youtube.com/watch?v=FTcUTww0gMU
# https://www.youtube.com/watch?v=A-pop39QLBY
# https://www.youtube.com/watch?v=OdFYaK_nUCs
# https://www.youtube.com/watch?v=DKeSsbnn33c
# https://www.youtube.com/watch?v=xZfTgV590kU
# https://www.youtube.com/watch?v=p0UYqN-wUh8
# https://www.youtube.com/watch?v=2aU_ASdsvtc
# https://www.youtube.com/watch?v=qvr8hBkYEFo
# https://www.youtube.com/watch?v=Jc1S1-2J2Og
# https://www.youtube.com/watch?v=vCnT8prUqFY
# https://www.youtube.com/watch?v=9WvexMiZ8dg
# https://www.youtube.com/watch?v=Chj5zdD5azs
# https://www.youtube.com/watch?v=Cp9v2tLG7Js
#
# Downloading and converting to .wav...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eGgraRbGduI
# [youtube] eGgraRbGduI: Downloading webpage
# [youtube] eGgraRbGduI: Downloading ios player API JSON
# [youtube] eGgraRbGduI: Downloading mweb player API JSON
# [youtube] eGgraRbGduI: Downloading m3u8 information
# [info] eGgraRbGduI: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio at the Whiskey Lounge.webm
# [download] 100% of   33.86MiB in 00:00:01 at 32.81MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio at the Whiskey Lounge.wav
# Deleting original file ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio at the Whiskey Lounge.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eJNQmU6UmEA
# [youtube] eJNQmU6UmEA: Downloading webpage
# [youtube] eJNQmU6UmEA: Downloading ios player API JSON
# [youtube] eJNQmU6UmEA: Downloading mweb player API JSON
# [youtube] eJNQmU6UmEA: Downloading m3u8 information
# [info] eJNQmU6UmEA: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Blue Monk - Jazz Guitar Trio.webm
# [download] 100% of    5.05MiB in 00:00:00 at 11.82MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Blue Monk - Jazz Guitar Trio.wav
# Deleting original file ./downloads/jazz guitar trio/Blue Monk - Jazz Guitar Trio.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=W2_gdQ20Mc8
# [youtube] W2_gdQ20Mc8: Downloading webpage
# [youtube] W2_gdQ20Mc8: Downloading ios player API JSON
# [youtube] W2_gdQ20Mc8: Downloading mweb player API JSON
# [youtube] W2_gdQ20Mc8: Downloading m3u8 information
# [info] W2_gdQ20Mc8: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio Live At Studio5 featuring Dennis Carroll and George Fludas.webm
# [download] 100% of   71.44MiB in 00:00:04 at 14.42MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio Live At Studio5 featuring Dennis Carroll and George Fludas.wav
# Deleting original file ./downloads/jazz guitar trio/Jazz Guitar Trio - Andy Brown Trio Live At Studio5 featuring Dennis Carroll and George Fludas.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xkLA7VHpGSQ
# [youtube] xkLA7VHpGSQ: Downloading webpage
# [youtube] xkLA7VHpGSQ: Downloading ios player API JSON
# [youtube] xkLA7VHpGSQ: Downloading mweb player API JSON
# [youtube] xkLA7VHpGSQ: Downloading m3u8 information
# [info] xkLA7VHpGSQ: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/John Stowell Trio ｜ Live at Ravenscroft - Jazzbird.webm
# [download] 100% of  111.65MiB in 00:00:02 at 41.92MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/John Stowell Trio ｜ Live at Ravenscroft - Jazzbird.wav
# Deleting original file ./downloads/jazz guitar trio/John Stowell Trio ｜ Live at Ravenscroft - Jazzbird.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uTM67UhBVxk
# [youtube] uTM67UhBVxk: Downloading webpage
# [youtube] uTM67UhBVxk: Downloading ios player API JSON
# [youtube] uTM67UhBVxk: Downloading mweb player API JSON
# [youtube] uTM67UhBVxk: Downloading m3u8 information
# [info] uTM67UhBVxk: Downloading 1 format(s): 140
# [download] Destination: ./downloads/jazz guitar trio/SCOTT DENETT THE NEW YORKER - Live Jazz Guitar Trio.m4a
# [download] 100% of   57.93MiB in 00:00:01 at 40.30MiB/s
# [FixupM4a] Correcting container of "./downloads/jazz guitar trio/SCOTT DENETT THE NEW YORKER - Live Jazz Guitar Trio.m4a"
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/SCOTT DENETT THE NEW YORKER - Live Jazz Guitar Trio.wav
# Deleting original file ./downloads/jazz guitar trio/SCOTT DENETT THE NEW YORKER - Live Jazz Guitar Trio.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FTcUTww0gMU
# [youtube] FTcUTww0gMU: Downloading webpage
# [youtube] FTcUTww0gMU: Downloading ios player API JSON
# [youtube] FTcUTww0gMU: Downloading mweb player API JSON
# [youtube] FTcUTww0gMU: Downloading m3u8 information
# [info] FTcUTww0gMU: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/🎸 Transatlantic Guitar Trio ⧸⧸ Richard Smith, Joscho Stephan & Rory Hoffman ⧸⧸ Live in Düsseldorf.webm
# [download] 100% of   46.42MiB in 00:00:01 at 34.54MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/🎸 Transatlantic Guitar Trio ⧸⧸ Richard Smith, Joscho Stephan & Rory Hoffman ⧸⧸ Live in Düsseldorf.wav
# Deleting original file ./downloads/jazz guitar trio/🎸 Transatlantic Guitar Trio ⧸⧸ Richard Smith, Joscho Stephan & Rory Hoffman ⧸⧸ Live in Düsseldorf.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=A-pop39QLBY
# [youtube] A-pop39QLBY: Downloading webpage
# [youtube] A-pop39QLBY: Downloading ios player API JSON
# [youtube] A-pop39QLBY: Downloading mweb player API JSON
# [youtube] A-pop39QLBY: Downloading m3u8 information
# [info] A-pop39QLBY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Satin Doll - Jazz Guitar Trio.webm
# [download] 100% of    4.16MiB in 00:00:00 at 13.54MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Satin Doll - Jazz Guitar Trio.wav
# Deleting original file ./downloads/jazz guitar trio/Satin Doll - Jazz Guitar Trio.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OdFYaK_nUCs
# [youtube] OdFYaK_nUCs: Downloading webpage
# [youtube] OdFYaK_nUCs: Downloading ios player API JSON
# [youtube] OdFYaK_nUCs: Downloading mweb player API JSON
# [youtube] OdFYaK_nUCs: Downloading m3u8 information
# [info] OdFYaK_nUCs: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Grant Green Trio (LIVE VIDEO 1969).webm
# [download] 100% of   32.64MiB in 00:00:00 at 33.60MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Grant Green Trio (LIVE VIDEO 1969).wav
# Deleting original file ./downloads/jazz guitar trio/Grant Green Trio (LIVE VIDEO 1969).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DKeSsbnn33c
# [youtube] DKeSsbnn33c: Downloading webpage
# [youtube] DKeSsbnn33c: Downloading ios player API JSON
# [youtube] DKeSsbnn33c: Downloading mweb player API JSON
# [youtube] DKeSsbnn33c: Downloading m3u8 information
# [info] DKeSsbnn33c: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Michael Kanan Trio - 12⧸3⧸2024.webm
# [download] 100% of  165.48MiB in 00:00:08 at 20.00MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Michael Kanan Trio - 12⧸3⧸2024.wav
# Deleting original file ./downloads/jazz guitar trio/Michael Kanan Trio - 12⧸3⧸2024.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xZfTgV590kU
# [youtube] xZfTgV590kU: Downloading webpage
# [youtube] xZfTgV590kU: Downloading ios player API JSON
# [youtube] xZfTgV590kU: Downloading mweb player API JSON
# [youtube] xZfTgV590kU: Downloading m3u8 information
# [info] xZfTgV590kU: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/￼Fender Player Jazz Bass Guitar, Maple FB, 3-Tone Sunburst.webm
# [download] 100% of  506.72KiB in 00:00:00 at 2.05MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/￼Fender Player Jazz Bass Guitar, Maple FB, 3-Tone Sunburst.wav
# Deleting original file ./downloads/jazz guitar trio/￼Fender Player Jazz Bass Guitar, Maple FB, 3-Tone Sunburst.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=p0UYqN-wUh8
# [youtube] p0UYqN-wUh8: Downloading webpage
# [youtube] p0UYqN-wUh8: Downloading ios player API JSON
# [youtube] p0UYqN-wUh8: Downloading mweb player API JSON
# [youtube] p0UYqN-wUh8: Downloading m3u8 information
# [info] p0UYqN-wUh8: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/I Remember You (Jazz Guitar Trio).webm
# [download] 100% of    3.32MiB in 00:00:00 at 8.74MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/I Remember You (Jazz Guitar Trio).wav
# Deleting original file ./downloads/jazz guitar trio/I Remember You (Jazz Guitar Trio).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2aU_ASdsvtc
# [youtube] 2aU_ASdsvtc: Downloading webpage
# [youtube] 2aU_ASdsvtc: Downloading ios player API JSON
# [youtube] 2aU_ASdsvtc: Downloading mweb player API JSON
# [youtube] 2aU_ASdsvtc: Downloading m3u8 information
# [info] 2aU_ASdsvtc: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio, Live in Buenos Aires.webm
# [download] 100% of   19.70MiB in 00:00:00 at 19.92MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Jazz Guitar Trio, Live in Buenos Aires.wav
# Deleting original file ./downloads/jazz guitar trio/Jazz Guitar Trio, Live in Buenos Aires.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qvr8hBkYEFo
# [youtube] qvr8hBkYEFo: Downloading webpage
# [youtube] qvr8hBkYEFo: Downloading ios player API JSON
# [youtube] qvr8hBkYEFo: Downloading mweb player API JSON
# [youtube] qvr8hBkYEFo: Downloading m3u8 information
# [info] qvr8hBkYEFo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/The Great Guitars： Barney Kessel, Charlie Byrd and Herb Ellis • 11-07-1982 • World of Jazz.webm
# [download] 100% of   68.85MiB in 00:00:02 at 33.82MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/The Great Guitars： Barney Kessel, Charlie Byrd and Herb Ellis • 11-07-1982 • World of Jazz.wav
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Jc1S1-2J2Og
# [youtube] Jc1S1-2J2Og: Downloading webpage
# [youtube] Jc1S1-2J2Og: Downloading ios player API JSON
# [youtube] Jc1S1-2J2Og: Downloading mweb player API JSON
# [youtube] Jc1S1-2J2Og: Downloading m3u8 information
# [info] Jc1S1-2J2Og: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Guitar Trio - Autumn Leaves.webm
# [download] 100% of    2.79MiB in 00:00:00 at 8.33MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Guitar Trio - Autumn Leaves.wav
# Deleting original file ./downloads/jazz guitar trio/Guitar Trio - Autumn Leaves.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vCnT8prUqFY
# [youtube] vCnT8prUqFY: Downloading webpage
# [youtube] vCnT8prUqFY: Downloading ios player API JSON
# [youtube] vCnT8prUqFY: Downloading mweb player API JSON
# [youtube] vCnT8prUqFY: Downloading m3u8 information
# [info] vCnT8prUqFY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Ed Bickert Trio - Street Of Dreams.webm
# [download] 100% of    3.69MiB in 00:00:00 at 10.87MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Ed Bickert Trio - Street Of Dreams.wav
# Deleting original file ./downloads/jazz guitar trio/Ed Bickert Trio - Street Of Dreams.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9WvexMiZ8dg
# [youtube] 9WvexMiZ8dg: Downloading webpage
# [youtube] 9WvexMiZ8dg: Downloading ios player API JSON
# [youtube] 9WvexMiZ8dg: Downloading mweb player API JSON
# [youtube] 9WvexMiZ8dg: Downloading m3u8 information
# [info] 9WvexMiZ8dg: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/KURT ROSENWINKEL Quartet feat ｜ Ben Wendel ｜ Ben Street ｜ Jeff Ballard.webm
# [download] 100% of   30.57MiB in 00:00:00 at 31.04MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/KURT ROSENWINKEL Quartet feat ｜ Ben Wendel ｜ Ben Street ｜ Jeff Ballard.wav
# Deleting original file ./downloads/jazz guitar trio/KURT ROSENWINKEL Quartet feat ｜ Ben Wendel ｜ Ben Street ｜ Jeff Ballard.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Chj5zdD5azs
# [youtube] Chj5zdD5azs: Downloading webpage
# [youtube] Chj5zdD5azs: Downloading ios player API JSON
# [youtube] Chj5zdD5azs: Downloading mweb player API JSON
# [youtube] Chj5zdD5azs: Downloading m3u8 information
# [info] Chj5zdD5azs: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Bill Frisell Trio ｜ Jazz ｜ Guitar.webm
# [download] 100% of   22.34MiB in 00:00:01 at 16.25MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Bill Frisell Trio ｜ Jazz ｜ Guitar.wav
# Deleting original file ./downloads/jazz guitar trio/Bill Frisell Trio ｜ Jazz ｜ Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Cp9v2tLG7Js
# [youtube] Cp9v2tLG7Js: Downloading webpage
# [youtube] Cp9v2tLG7Js: Downloading ios player API JSON
# [youtube] Cp9v2tLG7Js: Downloading mweb player API JSON
# [youtube] Cp9v2tLG7Js: Downloading m3u8 information
# [info] Cp9v2tLG7Js: Downloading 1 format(s): 251
# [download] Destination: ./downloads/jazz guitar trio/Nick Hempton Quartet - Live At Smalls Jazz Club -12⧸01⧸2024.webm
# [download] 100% of  138.44MiB in 00:00:07 at 17.45MiB/s
# [ExtractAudio] Destination: ./downloads/jazz guitar trio/Nick Hempton Quartet - Live At Smalls Jazz Club -12⧸01⧸2024.wav
# Deleting original file ./downloads/jazz guitar trio/Nick Hempton Quartet - Live At Smalls Jazz Club -12⧸01⧸2024.webm (pass -k to keep)
#
# Process complete!
# Searching YouTube for: neo soul guitar instrumental live record
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: neo soul guitar instrumental live record
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: neo soul guitar instrumental live record
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: neo soul guitar instrumental live record
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: neo soul guitar instrumental live record
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Found 18 videos: https://www.youtube.com/watch?v=KQWQEbvth8o
# https://www.youtube.com/watch?v=1MSRHUKncU0
# https://www.youtube.com/watch?v=3VNm3rGXPXs
# https://www.youtube.com/watch?v=polOG2kXTkQ
# https://www.youtube.com/watch?v=5zqlgMh4aYs
# https://www.youtube.com/watch?v=7x3svtckdhY
# https://www.youtube.com/watch?v=z-KsEPcsbls
# https://www.youtube.com/watch?v=VZItGcbUTNY
# https://www.youtube.com/watch?v=s4U1TmDbeB8
# https://www.youtube.com/watch?v=DnU3hrvMPk0
# https://www.youtube.com/watch?v=eHE_odJq8uU
# https://www.youtube.com/watch?v=CTnf9wqIuIY
# https://www.youtube.com/watch?v=WZqyiL3o0u0
# https://www.youtube.com/watch?v=J016xjUYkWI
# https://www.youtube.com/watch?v=qORwZ2opdvM
# https://www.youtube.com/watch?v=w4WmIjqBl94
# https://www.youtube.com/watch?v=TqQv3CENif0
# https://www.youtube.com/watch?v=6yQa0gyfMLU
#
# Downloading and converting to .wav...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KQWQEbvth8o
# [youtube] KQWQEbvth8o: Downloading webpage
# [youtube] KQWQEbvth8o: Downloading ios player API JSON
# [youtube] KQWQEbvth8o: Downloading mweb player API JSON
# [youtube] KQWQEbvth8o: Downloading m3u8 information
# [info] KQWQEbvth8o: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2024 ⧸ Neo-Soul Guitar powered by SHURE.webm
# [download] 100% of   26.82MiB in 00:00:00 at 34.73MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2024 ⧸ Neo-Soul Guitar powered by SHURE.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2024 ⧸ Neo-Soul Guitar powered by SHURE.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1MSRHUKncU0
# [youtube] 1MSRHUKncU0: Downloading webpage
# [youtube] 1MSRHUKncU0: Downloading ios player API JSON
# [youtube] 1MSRHUKncU0: Downloading mweb player API JSON
# [youtube] 1MSRHUKncU0: Downloading m3u8 information
# [info] 1MSRHUKncU0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm
# [download] 100% of   19.74MiB in 00:00:01 at 16.26MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3VNm3rGXPXs
# [youtube] 3VNm3rGXPXs: Downloading webpage
# [youtube] 3VNm3rGXPXs: Downloading ios player API JSON
# [youtube] 3VNm3rGXPXs: Downloading mweb player API JSON
# [youtube] 3VNm3rGXPXs: Downloading m3u8 information
# [info] 3VNm3rGXPXs: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/⌚ 1 HOUR of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.webm
# [download] 100% of   73.88MiB in 00:00:02 at 36.41MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/⌚ 1 HOUR of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/⌚ 1 HOUR of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=polOG2kXTkQ
# [youtube] polOG2kXTkQ: Downloading webpage
# [youtube] polOG2kXTkQ: Downloading ios player API JSON
# [youtube] polOG2kXTkQ: Downloading mweb player API JSON
# [youtube] polOG2kXTkQ: Downloading m3u8 information
# [info] polOG2kXTkQ: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/𝐍𝐞𝐨 𝐬𝐨𝐮𝐥 𝐆𝐮𝐢𝐭𝐚𝐫 & 𝐉𝐚𝐦 𝐩𝐥𝐚𝐲𝐥𝐢𝐬𝐭.webm
# [download] 100% of   59.60MiB in 00:00:01 at 40.17MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/𝐍𝐞𝐨 𝐬𝐨𝐮𝐥 𝐆𝐮𝐢𝐭𝐚𝐫 & 𝐉𝐚𝐦 𝐩𝐥𝐚𝐲𝐥𝐢𝐬𝐭.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/𝐍𝐞𝐨 𝐬𝐨𝐮𝐥 𝐆𝐮𝐢𝐭𝐚𝐫 & 𝐉𝐚𝐦 𝐩𝐥𝐚𝐲𝐥𝐢𝐬𝐭.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5zqlgMh4aYs
# [youtube] 5zqlgMh4aYs: Downloading webpage
# [youtube] 5zqlgMh4aYs: Downloading ios player API JSON
# [youtube] 5zqlgMh4aYs: Downloading mweb player API JSON
# [youtube] 5zqlgMh4aYs: Downloading m3u8 information
# [info] 5zqlgMh4aYs: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Feel Like Makin' Love - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm
# [download] 100% of    7.91MiB in 00:00:00 at 20.58MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Feel Like Makin' Love - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Feel Like Makin' Love - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7x3svtckdhY
# [youtube] 7x3svtckdhY: Downloading webpage
# [youtube] 7x3svtckdhY: Downloading ios player API JSON
# [youtube] 7x3svtckdhY: Downloading mweb player API JSON
# [youtube] 7x3svtckdhY: Downloading m3u8 information
# [info] 7x3svtckdhY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima CANAL SIDE Neo-Soul Guitar SESSION ｜ TENNOZ CANAL FES 2024 -SPRING⧸SUMMER-.webm
# [download] 100% of   29.07MiB in 00:00:00 at 37.75MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima CANAL SIDE Neo-Soul Guitar SESSION ｜ TENNOZ CANAL FES 2024 -SPRING⧸SUMMER-.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima CANAL SIDE Neo-Soul Guitar SESSION ｜ TENNOZ CANAL FES 2024 -SPRING⧸SUMMER-.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z-KsEPcsbls
# [youtube] z-KsEPcsbls: Downloading webpage
# [youtube] z-KsEPcsbls: Downloading ios player API JSON
# [youtube] z-KsEPcsbls: Downloading mweb player API JSON
# [youtube] z-KsEPcsbls: Downloading m3u8 information
# [info] z-KsEPcsbls: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima × Kyohei Ariga Live in Kimama Studio 2024 (Neo-Soul Guitar).webm
# [download] 100% of   15.89MiB in 00:00:00 at 48.00MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima × Kyohei Ariga Live in Kimama Studio 2024 (Neo-Soul Guitar).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima × Kyohei Ariga Live in Kimama Studio 2024 (Neo-Soul Guitar).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VZItGcbUTNY
# [youtube] VZItGcbUTNY: Downloading webpage
# [youtube] VZItGcbUTNY: Downloading ios player API JSON
# [youtube] VZItGcbUTNY: Downloading mweb player API JSON
# [youtube] VZItGcbUTNY: Downloading m3u8 information
# [info] VZItGcbUTNY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima Live at Tower Records Shibuya (Neo-Soul Guitar).webm
# [download] 100% of   17.27MiB in 00:00:00 at 23.48MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima Live at Tower Records Shibuya (Neo-Soul Guitar).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima Live at Tower Records Shibuya (Neo-Soul Guitar).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s4U1TmDbeB8
# [youtube] s4U1TmDbeB8: Downloading webpage
# [youtube] s4U1TmDbeB8: Downloading ios player API JSON
# [youtube] s4U1TmDbeB8: Downloading mweb player API JSON
# [youtube] s4U1TmDbeB8: Downloading m3u8 information
# [info] s4U1TmDbeB8: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/(FREE) ALTERNATIVE R&B x NEO SOUL TYPE BEAT ''Take a moment''.webm
# [download] 100% of    2.67MiB in 00:00:01 at 1.70MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/(FREE) ALTERNATIVE R&B x NEO SOUL TYPE BEAT ''Take a moment''.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/(FREE) ALTERNATIVE R&B x NEO SOUL TYPE BEAT ''Take a moment''.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DnU3hrvMPk0
# [youtube] DnU3hrvMPk0: Downloading webpage
# [youtube] DnU3hrvMPk0: Downloading ios player API JSON
# [youtube] DnU3hrvMPk0: Downloading mweb player API JSON
# [youtube] DnU3hrvMPk0: Downloading m3u8 information
# [info] DnU3hrvMPk0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Neo-Soul Guitar Jam Track (key of Em).webm
# [download] 100% of    6.41MiB in 00:00:00 at 13.70MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Neo-Soul Guitar Jam Track (key of Em).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Neo-Soul Guitar Jam Track (key of Em).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eHE_odJq8uU
# [youtube] eHE_odJq8uU: Downloading webpage
# [youtube] eHE_odJq8uU: Downloading ios player API JSON
# [youtube] eHE_odJq8uU: Downloading mweb player API JSON
# [youtube] eHE_odJq8uU: Downloading m3u8 information
# [info] eHE_odJq8uU: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/⌚ 2 HOUR 30 of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.webm
# [download] 100% of  161.31MiB in 00:00:03 at 41.19MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/⌚ 2 HOUR 30 of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/⌚ 2 HOUR 30 of NEO SOUL Instrumental Music (Relaxing ⧸ Calming ⧸ Chill) LONG MIX.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CTnf9wqIuIY
# [youtube] CTnf9wqIuIY: Downloading webpage
# [youtube] CTnf9wqIuIY: Downloading ios player API JSON
# [youtube] CTnf9wqIuIY: Downloading mweb player API JSON
# [youtube] CTnf9wqIuIY: Downloading m3u8 information
# [info] CTnf9wqIuIY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima & Nahokimama Live in Tokyo (Neo-Soul Guitar).webm
# [download] 100% of   16.04MiB in 00:00:00 at 18.65MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Toshiki Soejima & Nahokimama Live in Tokyo (Neo-Soul Guitar).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Toshiki Soejima & Nahokimama Live in Tokyo (Neo-Soul Guitar).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WZqyiL3o0u0
# [youtube] WZqyiL3o0u0: Downloading webpage
# [youtube] WZqyiL3o0u0: Downloading ios player API JSON
# [youtube] WZqyiL3o0u0: Downloading mweb player API JSON
# [youtube] WZqyiL3o0u0: Downloading m3u8 information
# [info] WZqyiL3o0u0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Isn't She Lovely - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm
# [download] 100% of    8.06MiB in 00:00:00 at 22.09MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Isn't She Lovely - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Isn't She Lovely - Toshiki Soejima ： Live & Recording 2022 ⧸ Neo-Soul Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J016xjUYkWI
# [youtube] J016xjUYkWI: Downloading webpage
# [youtube] J016xjUYkWI: Downloading ios player API JSON
# [youtube] J016xjUYkWI: Downloading mweb player API JSON
# [youtube] J016xjUYkWI: Downloading m3u8 information
# [info] J016xjUYkWI: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/What's Going On - Toshiki Soejima (Live Recording 2022)(Neo-Soul Guitar).webm
# [download] 100% of    7.66MiB in 00:00:00 at 19.21MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/What's Going On - Toshiki Soejima (Live Recording 2022)(Neo-Soul Guitar).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/What's Going On - Toshiki Soejima (Live Recording 2022)(Neo-Soul Guitar).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qORwZ2opdvM
# [youtube] qORwZ2opdvM: Downloading webpage
# [youtube] qORwZ2opdvM: Downloading ios player API JSON
# [youtube] qORwZ2opdvM: Downloading mweb player API JSON
# [youtube] qORwZ2opdvM: Downloading m3u8 information
# [info] qORwZ2opdvM: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima (feat.Kyohei Ariga)(Neo-Soul Guitar).webm
# [download] 100% of    7.03MiB in 00:00:00 at 15.90MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima (feat.Kyohei Ariga)(Neo-Soul Guitar).wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima (feat.Kyohei Ariga)(Neo-Soul Guitar).webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=w4WmIjqBl94
# [youtube] w4WmIjqBl94: Downloading webpage
# [youtube] w4WmIjqBl94: Downloading ios player API JSON
# [youtube] w4WmIjqBl94: Downloading mweb player API JSON
# [youtube] w4WmIjqBl94: Downloading m3u8 information
# [info] w4WmIjqBl94: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima ： Live & Recording 2023 ⧸ Neo-Soul Guitar.webm
# [download] 100% of    9.24MiB in 00:00:00 at 43.71MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima ： Live & Recording 2023 ⧸ Neo-Soul Guitar.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Just The Two Of Us - Toshiki Soejima ： Live & Recording 2023 ⧸ Neo-Soul Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TqQv3CENif0
# [youtube] TqQv3CENif0: Downloading webpage
# [youtube] TqQv3CENif0: Downloading ios player API JSON
# [youtube] TqQv3CENif0: Downloading mweb player API JSON
# [youtube] TqQv3CENif0: Downloading m3u8 information
# [info] TqQv3CENif0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/neo soul guitar instrumental live record/Neo Soul Guitar.webm
# [download] 100% of    4.49MiB in 00:00:00 at 10.77MiB/s
# [ExtractAudio] Destination: ./downloads/neo soul guitar instrumental live record/Neo Soul Guitar.wav
# Deleting original file ./downloads/neo soul guitar instrumental live record/Neo Soul Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6yQa0gyfMLU
# [youtube] 6yQa0gyfMLU: Downloading webpage
# [youtube] 6yQa0gyfMLU: Downloading ios player API JSON
# ...
# [youtube] T-U3c1nU3eM: Downloading webpage
# [youtube] T-U3c1nU3eM: Downloading ios player API JSON
# [youtube] T-U3c1nU3eM: Downloading mweb player API JSON
# [youtube] T-U3c1nU3eM: Downloading m3u8 information
# [info] T-U3c1nU3eM: Downloading 1 format(s): 251
# [download] Destination: ./downloads/best acoustic guitar rock songs/TOP 30 songs for ACOUSTIC guitar!.webm
# [download] 100% of   14.83MiB in 00:00:00 at 28.99MiB/s
# [ExtractAudio] Destination: ./downloads/best acoustic guitar rock songs/TOP 30 songs for ACOUSTIC guitar!.wav
# Deleting original file ./downloads/best acoustic guitar rock songs/TOP 30 songs for ACOUSTIC guitar!.webm (pass -k to keep)
#
# Process complete!
# Searching YouTube for: guitar live performance old songs
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: guitar live performance old songs
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['reelShelfRenderer'])
# WARNING:pytube.contrib.search:Search term: guitar live performance old songs
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: guitar live performance old songs
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# WARNING:pytube.contrib.search:Unexpected renderer encountered.
# WARNING:pytube.contrib.search:Renderer name: dict_keys(['lockupViewModel'])
# WARNING:pytube.contrib.search:Search term: guitar live performance old songs
# WARNING:pytube.contrib.search:Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Found 18 videos: https://www.youtube.com/watch?v=2rwfqsjimRM
# https://www.youtube.com/watch?v=zWVqNrEhY4g
# https://www.youtube.com/watch?v=syKZdZJeqGU
# https://www.youtube.com/watch?v=uOx0mQ7wLZs
# https://www.youtube.com/watch?v=09839DpTctU
# https://www.youtube.com/watch?v=OuVIJlSDOs0
# https://www.youtube.com/watch?v=VVwMuxqLiy8
# https://www.youtube.com/watch?v=9Iibj8bpr6Q
# https://www.youtube.com/watch?v=CrTMc2i6Lzc
# https://www.youtube.com/watch?v=LNrAFb3I2js
# https://www.youtube.com/watch?v=WZn9QZykx10
# https://www.youtube.com/watch?v=bm03wqLY3Nc
# https://www.youtube.com/watch?v=e26zZ83Oh6Y
# https://www.youtube.com/watch?v=An2a1_Do_fc
# https://www.youtube.com/watch?v=qvr8hBkYEFo
# https://www.youtube.com/watch?v=UOwvmgjbwDo
# https://www.youtube.com/watch?v=EgmLuloZN3A
# https://www.youtube.com/watch?v=zlKLtnbU0xE
#
# Downloading and converting to .wav...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2rwfqsjimRM
# [youtube] 2rwfqsjimRM: Downloading webpage
# [youtube] 2rwfqsjimRM: Downloading ios player API JSON
# [youtube] 2rwfqsjimRM: Downloading mweb player API JSON
# [youtube] 2rwfqsjimRM: Downloading m3u8 information
# [info] 2rwfqsjimRM: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar live performance old songs/Santo & Johnny ＂Sleep Walk＂.webm
# [download] 100% of    2.47MiB in 00:00:00 at 9.24MiB/s
# [ExtractAudio] Destination: ./downloads/guitar live performance old songs/Santo & Johnny ＂Sleep Walk＂.wav
# Deleting original file ./downloads/guitar live performance old songs/Santo & Johnny ＂Sleep Walk＂.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zWVqNrEhY4g
# [youtube] zWVqNrEhY4g: Downloading webpage
# [youtube] zWVqNrEhY4g: Downloading ios player API JSON
# [youtube] zWVqNrEhY4g: Downloading mweb player API JSON
# [youtube] zWVqNrEhY4g: Downloading m3u8 information
# [info] zWVqNrEhY4g: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar live performance old songs/Dido Acoustic Mix ｜ Best Live Acoustic Performances.webm
# [download] 100% of   79.97MiB in 00:00:02 at 35.40MiB/s
# [ExtractAudio] Destination: ./downloads/guitar live performance old songs/Dido Acoustic Mix ｜ Best Live Acoustic Performances.wav
# Deleting original file ./downloads/guitar live performance old songs/Dido Acoustic Mix ｜ Best Live Acoustic Performances.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=syKZdZJeqGU
# [youtube] syKZdZJeqGU: Downloading webpage
# [youtube] syKZdZJeqGU: Downloading ios player API JSON
# [youtube] syKZdZJeqGU: Downloading mweb player API JSON
# [youtube] syKZdZJeqGU: Downloading m3u8 information
# [info] syKZdZJeqGU: Downloading 1 format(s): 251
# [download] Destination: ./downloads/guitar live performance old songs/40 FINGERS - A Guitar Night in Ljubljana (Full Live Performance) - Fingerstyle Guitar.webm
# [download] 100% of   94.88MiB in 00:00:02 at 46.79MiB/s
# [ExtractAudio] Destination: ./downloads/guitar live performance old songs/40 FINGERS - A Guitar Night in Ljubljana (Full Live Performance) - Fingerstyle Guitar.wav
# Deleting original file ./downloads/guitar live performance old songs/40 FINGERS - A Guitar Night in Ljubljana (Full Live Performance) - Fingerstyle Guitar.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uOx0mQ7wLZs
# [youtube] uOx0mQ7wLZs: Downloading webpage
# [youtube] uOx0mQ7wLZs: Downloading ios player API JSON
# [youtube] uOx0mQ7wLZs: Downloading mweb player API JSON
# [youtube] uOx0mQ7wLZs: Downloading m3u8 information
# [youtube] uOx0mQ7wLZs: Downloading m3u8 information
# [info] uOx0mQ7wLZs: Downloading 1 format(s): 234
# [download] Destination: ./downloads/guitar live performance old songs/Great Relaxing Guitar Music Of All Time - Sweet Guitar Melodies Bring You Back To Your Youth 2024-12-05 10_45.mp4
# [ffmpeg] Interrupted by user
# [download] 100% of  236.94MiB in 03:27:23 at 19.50KiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "./downloads/guitar live performance old songs/Great Relaxing Guitar Music Of All Time - Sweet Guitar Melodies Bring You Back To Your Youth 2024-12-05 10_45.mp4"
# [ExtractAudio] Destination: ./downloads/guitar live performance old songs/Great Relaxing Guitar Music Of All Time - Sweet Guitar Melodies Bring You Back To Your Youth 2024-12-05 10_45.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-2d27dbcd3773> in <cell line: 5>()
#       3 get_yt_music("neo soul guitar instrumental live record", 20)
#       4 get_yt_music("best acoustic guitar rock songs", 20)
# ----> 5 get_yt_music("guitar live performance old songs", 20)
#
# <ipython-input-33-14031e363519> in get_yt_music(keywords, max_results)
#      34
#      35     print("\nDownloading and converting to .wav...")
# ---> 36     download_and_convert_to_wav(video_links, output_folder = f"./downloads/{keywords}")
#      37     print("\nProcess complete!")
#
# <ipython-input-33-14031e363519> in download_and_convert_to_wav(video_links, output_folder)
#      23         for link in video_links:
#      24             try:
# ---> 25                 ydl.download([link])
#      26             except Exception as e:
#      27                 print(f"Failed to download {link}: {e}")
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in download(self, url_list)
#    3603
#    3604         for url in url_list:
# -> 3605             self.__download_wrapper(self.extract_info)(
#    3606                 url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3607
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(*args, **kwargs)
#    3576         def wrapper(*args, **kwargs):
#    3577             try:
# -> 3578                 res = func(*args, **kwargs)
#    3579             except CookieLoadError:
#    3580                 raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1611                     raise ExistingVideoReached
#    1612                 break
# -> 1613             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1614         else:
#    1615             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1622             while True:
#    1623                 try:
# -> 1624                     return func(self, *args, **kwargs)
#    1625                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1626                     raise
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1778         if process:
#    1779             self._wait_for_video(ie_result)
# -> 1780             return self.process_ie_result(ie_result, download, extra_info)
#    1781         else:
#    1782             return ie_result
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1837         if result_type == 'video':
#    1838             self.add_extra_info(ie_result, extra_info)
# -> 1839             ie_result = self.process_video_result(ie_result, download=download)
#    1840             self._raise_pending_errors(ie_result)
#    1841             additional_urls = (ie_result or {}).get('additional_urls')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_video_result(self, info_dict, download)
#    3009                 downloaded_formats.append(new_info)
#    3010                 try:
# -> 3011                     self.process_info(new_info)
#    3012                 except MaxDownloadsReached:
#    3013                     max_downloads_reached = True
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     175     def wrapper(self, *args, **kwargs):
#     176         try:
# --> 177             return func(self, *args, **kwargs)
#     178         except _UnsafeExtensionError as error:
#     179             self.report_error(
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in process_info(self, info_dict)
#    3555                 fixup()
#    3556                 try:
# -> 3557                     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3558                 except PostProcessingError as err:
#    3559                     self.report_error(f'Postprocessing: {err}')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in post_process(self, filename, info, files_to_move)
#    3739         info['filepath'] = filename
#    3740         info['__files_to_move'] = files_to_move or {}
# -> 3741         info = self.run_all_pps('post_process', info, additional_pps=info.get('__postprocessors'))
#    3742         info = self.run_pp(MoveFilesAfterDownloadPP(self), info)
#    3743         del info['__files_to_move']
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in run_all_pps(self, key, info, additional_pps)
#    3721             self._forceprint(key, info)
#    3722         for pp in (additional_pps or []) + self._pps[key]:
# -> 3723             info = self.run_pp(pp, info)
#    3724         return info
#    3725
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/YoutubeDL.py in run_pp(self, pp, infodict)
#    3699             infodict['__files_to_move'] = {}
#    3700         try:
# -> 3701             files_to_delete, infodict = pp.run(infodict)
#    3702         except PostProcessingError as e:
#    3703             # Must be True and not 'only_download'
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/common.py in run(self, info, *args, **kwargs)
#      20             info_copy = self._copy_infodict(info)
#      21             self._hook_progress({'status': 'started'}, info_copy)
# ---> 22             ret = func(self, info, *args, **kwargs)
#      23             if ret is not None:
#      24                 _, info = ret
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/common.py in wrapper(self, info)
#     125                     else 'images')
#     126                 if allowed[format_type]:
# --> 127                     return func(self, info)
#     128                 else:
#     129                     self.to_screen(f'Skipping {format_type}')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/ffmpeg.py in run(self, information)
#     528
#     529         self.to_screen(f'Destination: {new_path}')
# --> 530         self.run_ffmpeg(path, temp_path, acodec, more_opts)
#     531
#     532         os.replace(path, orig_path)
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/ffmpeg.py in run_ffmpeg(self, path, out_path, codec, more_opts)
#     477         opts = ['-vn', *acodec_opts, *more_opts]
#     478         try:
# --> 479             FFmpegPostProcessor.run_ffmpeg(self, path, out_path, opts)
#     480         except FFmpegPostProcessorError as err:
#     481             raise PostProcessingError(f'audio conversion failed: {err.msg}')
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/ffmpeg.py in run_ffmpeg(self, path, out_path, opts, **kwargs)
#     372
#     373     def run_ffmpeg(self, path, out_path, opts, **kwargs):
# --> 374         return self.run_ffmpeg_multiple_files([path], out_path, opts, **kwargs)
#     375
#     376     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/ffmpeg.py in run_ffmpeg_multiple_files(self, input_paths, out_path, opts, **kwargs)
#     327
#     328     def run_ffmpeg_multiple_files(self, input_paths, out_path, opts, **kwargs):
# --> 329         return self.real_run_ffmpeg(
#     330             [(path, []) for path in input_paths],
#     331             [(out_path, opts)], **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/postprocessor/ffmpeg.py in real_run_ffmpeg(self, input_path_opts, output_path_opts, expected_retcodes)
#     361
#     362         self.write_debug(f'ffmpeg command line: {shell_quote(cmd)}')
# --> 363         _, stderr, returncode = Popen.run(
#     364             cmd, text=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, stdin=subprocess.PIPE)
#     365         if returncode not in variadic(expected_retcodes):
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/utils/_utils.py in run(cls, timeout, *args, **kwargs)
#     904         with cls(*args, **kwargs) as proc:
#     905             default = '' if proc.__text_mode else b''
# --> 906             stdout, stderr = proc.communicate_or_kill(timeout=timeout)
#     907             return stdout or default, stderr or default, proc.returncode
#     908
#
# /usr/local/lib/python3.10/dist-packages/yt_dlp/utils/_utils.py in communicate_or_kill(self, *args, **kwargs)
#     890     def communicate_or_kill(self, *args, **kwargs):
#     891         try:
# --> 892             return self.communicate(*args, **kwargs)
#     893         except BaseException:  # Including KeyboardInterrupt
#     894             self.kill(timeout=None)
#
# /usr/lib/python3.10/subprocess.py in communicate(self, input, timeout)
#    1152
#    1153             try:
# -> 1154                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1155             except KeyboardInterrupt:
#    1156                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.10/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2019                             'failed to raise TimeoutExpired.')
#    2020
# -> 2021                     ready = selector.select(timeout)
#    2022                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2023
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ### Resize YT Music (to 30 sec chunks)

# %%
import random
random.seed(42)

def reformat_filename(filename: str) -> str:
    return (
        filename
        .replace("⧸", "|")
        .replace(" ", "_")
        .lower()
        [:-4][:50]
    ) + "_.wav"

def chunk_audio_files(
        audio_files: List[str],
        output_dir: str = "./yt_music",
        chunk_sec: int = 30,
        max_chunks_per_video: int = 10,
    ):
    # create output dir
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # chunk
    for f in audio_files:
        audio, sr = librosa.load(f, sr=32000)
        chunk_size = sr * chunk_sec
        num_chunks = len(audio) // chunk_size
        filename = reformat_filename(os.path.basename(f))

        # drop first two and last two chunks, random samples at most max_chunks_per_video
        if num_chunks - 4 > max_chunks_per_video:
            iters = random.sample(range(2, num_chunks - 2), max_chunks_per_video)
        else:
            iters = range(1, num_chunks - 1)

        for i in iters:
            start = i * chunk_size
            end = start + chunk_size
            chunk = audio[start:end]
            output_path = os.path.join(output_dir, f"{filename[:-4]}_{i}.wav")
            sf.write(output_path, chunk, sr)

    print(f"Total {len(glob.glob(output_dir + '/*.wav'))} audio files chunked and saved to {output_dir}")
    return

# %%
folders = [
    "guitar jamming session",
    "jazz guitar trio",
    "neo soul guitar instrumental live record",
    "best acoustic guitar rock songs",
    "guitar live performance old songs"
]
for folder in folders:
    audio_path = f"./downloads/{folder}"
    audio_files = glob.glob(audio_path + "/*.wav")
    chunk_audio_files(audio_files, output_dir = f"/content/drive/MyDrive/GuitarJam/yt_music/{folder}")
# Out:
# Total 164 audio files chunked and saved to /content/drive/MyDrive/GuitarJam/yt_music/guitar live performance old songs

# %% [markdown]
# ### Check the audio files

# %%
from IPython.display import Audio

# %%
Audio("/content/drive/MyDrive/GuitarJam/yt_music/guitar live performance old songs/40_fingers_-_a_guitar_night_in_ljubljana_(full_liv__132.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Re-organize Dataset Folder

# %% [markdown]
# ### Create metadata

# %%
if not os.path.exists("/content/drive/MyDrive/GuitarJam/yt_music_dataset"):
    os.mkdir("/content/drive/MyDrive/GuitarJam/yt_music_dataset")
    os.mkdir("/content/drive/MyDrive/GuitarJam/yt_music_dataset/train")

# %%
folders = [
    "guitar jamming session",
    "jazz guitar trio",
    "neo soul guitar instrumental live record",
    "best acoustic guitar rock songs",
    "guitar live performance old songs"
]

meta = pd.DataFrame(columns = ["file_name", "prompt"])
for folder in folders:
    filenames = glob.glob(f"/content/drive/MyDrive/GuitarJam/yt_music/{folder}/*.wav")
    print(f"Files count in `{folder}`: {len(filenames)}")
    new_filenames = [f"train/{os.path.basename(f)}" for f in filenames]
    prompts = [f"Music with Guitar, Guitar, Guitar - {folder} | "] * len(filenames)
    df = pd.DataFrame({"file_name": new_filenames, "prompt": prompts})
    meta = pd.concat([meta, df], axis=0, ignore_index=True)

meta.to_csv("/content/drive/MyDrive/GuitarJam/yt_music_dataset/metadata.csv", index=False)
print("---"*10)
print(f"Total files count: {len(meta)}")
# Out:
# Files count in `guitar jamming session`: 161
# Files count in `jazz guitar trio`: 151
# Files count in `neo soul guitar instrumental live record`: 144
# Files count in `best acoustic guitar rock songs`: 100
# Files count in `guitar live performance old songs`: 144
# ------------------------------
# Total files count: 700

# %% [markdown]
# ### Move the Files

# %%
source_base_path = "/content/drive/MyDrive/GuitarJam/yt_music"
target_path = "/content/drive/MyDrive/GuitarJam/yt_music_dataset/train"

for folder in folders:
    source_path = os.path.join(source_base_path, folder)

    if os.path.exists(source_path):
        for file_name in os.listdir(source_path):
            if file_name.endswith(".wav"):
                file_path = os.path.join(source_path, file_name)

                # overwrite if exists
                shutil.move(file_path, os.path.join(target_path, file_name))
    else:
        print(f"Source folder {source_path} does not exist.")

# %%
for folder in folders:
    if len(glob.glob(f"/content/drive/MyDrive/GuitarJam/yt_music/{folder}/*.wav")) == 0:
        # !rm -rf /content/drive/MyDrive/GuitarJam/yt_music/{folder}
